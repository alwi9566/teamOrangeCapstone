# %%
import requests
import bs4 as beautifulSoup

# %%
# dictionary of listing links

#facebook links expire, so we need to use new listing links likely every 24 hrs
linkDict = {'facebook': "https://www.facebook.com/marketplace/item/1880470092826974/?ref=browse_tab&referral_code=marketplace_top_picks&referral_story_type=top_picks",
            'ebay': 'https://www.ebay.com/itm/375566255823?itmmeta=01K61AHZFV7J8YM6ASDR7B7DJZ&hash=item57717e46cf:g:Z5sAAeSw79lou1AX&itmprp=enc%3AAQAKAAAA4AYiKrcLdLA5QJvOiNupZlSduAS97NIRyYbElbIJIC4xoIWi4iIf76W5zrApivCWrpbyRDqg5%2B605vVVisYksvajACjCZHaBr6ctpsN7TdRcvhtFhvBMQTJ%2BAaMwg8I4wYqMdmJ%2FOZhsFrwAk5j3kWIzi6abx5qYVMiOYddd5rewEaNcIFRyJcoatbraIEMTYe6zkFJi1kPZTI8XydJbIzF6fX2JeTCgF4z9tIn%2BTa%2BD%2BIgFOTranuP0yWwWVLOk%2BFxvbSdquPfvtC%2FGrvVnEZlCgCI%2FHzwemDS6t4%2FtuZne%7Ctkp%3ABk9SR4L4x6qwZg',
            'craigslist': ''
            }

# spoof request from browser
headers = {'User-Agent': 'Mozilla/5.0 Windows NT 10.0; Win64; x64',
           #'Referer': 'https://www.facebook.com/marketplace/'
           }

# marketplaceSoup = beautifulSoup.BeautifulSoup(requests.get(marketplaceListing, headers=headers).text, 'lxml')
# craigslistSoup = beautifulSoup.BeautifulSoup(requests.get(craigslistListing, headers=headers).text, 'lxml')
# ebaySoup = beautifulSoup.BeautifulSoup(requests.get(ebayListing, headers=headers).text, 'lxml')

# %%
# make soup using listing from exampleList
listingSoup = beautifulSoup.BeautifulSoup(requests.get(linkDict['ebay'], headers=headers).text, 'html.parser')
print(listingSoup.prettify())
# Out:
# <!--M_96613636#s0-2-->
# <!--M_96613636^s0-2-1 s0-2 1-->
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/>
#   <link href="//p.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//q.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//pics.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/>
#   <link href="//reco.ebay.com" rel="dns-prefetch"/>
#   <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#   <link href="//rover.ebay.com" rel="dns-prefetch"/>
#   <script>
#    $ssgST=new Date().getTime();
#   </script>
#   <!--M_96613636^s0-2-1-4 s0-2-1 4-->
#   <!--M_96613636/-->
#   <script data-inlinepayload='{"loggerProps":{"serviceName":"r1vinode","serviceConsumerId":"urn:ebay-marketplace-consumerid:31be3645-70d4-467d-a381-1d97473133f4","serviceVersion":"r1vinode-2.0.0_20250925145652706","siteId":0,"environment":"production","captureUncaught":true,"captureUnhandledRejections":true,"endpoint":"https://svcs.ebay.com/","pool":"r1r1vinode45cont","ignoreList":["_AutofillCallbackHandler","\\$_mod"]}}' type="text/javascript">
#    (()=>{"use strict";const e={unstructured:{message:"string"},event:{kind:"string",detail:"string"},exception:{"exception.type":"string","exception.message":"string","exception.stacktrace":"string","exception.url":"string"}},t=JSON.parse('{"logs":"https://ir.ebaystatic.com/cr/v/c01/logs.dae067de06d6d3663c6f.bundle.js"}');const r=(e,t)=>{const r="undefined"!=typeof window?window.location.href:"/index.js";return{type:"exception","exception.context":t||"","exception.type":e?.name||"","exception.message":e?.message||"","exception.stacktrace":e?.stack||"","exception.url":r}},n=(e,r,n)=>{let o=!1;const i=[];let a=e=>{o?(e=>{console.warn("Logger failed initialization (see earlier error logs) — failed to send log: ",e)})(e):i.push(e)};return n({event:"Preload",value:a}),(async e=>{let r=2;const n=async()=>{let o;r--;try{o=await import(t[e])}catch(e){if(r>0)return console.error("@ebay/rum-web failed to lazy load module; retrying",e),n();throw console.error("@ebay/rum-web failed to lazy load module; fatal",e),e}return function(e,t){if("object"!=typeof(r=e)||null===r||Array.isArray(r)||e.key!==t||void 0===e.factory)throw new Error("Invalid module loaded");var r}(o,e),o};return n()})("logs").then((t=>{const{factory:n}=t;return n(e,r)})).then((e=>{a=e,n({event:"Complete",value:a}),i.forEach((e=>a(e))),i.length=0})).catch((e=>{console.error(e.message),o=!0,n({event:"Error",value:e}),i.forEach((e=>a(e))),i.length=0})),t=>{((e,t)=>"shouldIgnore"in e&&void 0!==e.shouldIgnore?e.shouldIgnore(t):"ignoreList"in e&&void 0!==e.ignoreList&&((e,t)=>null!==Object.values(e).filter(Boolean).join(" ").match(t))(t,e.ignoreList))(e,t)||a(t)}},o=e=>({log:t=>e({type:"unstructured",message:t}),error:(t,n)=>e(r(t,n)),event:t=>e(t)}),i="@ebay/rum/request-status",a=Symbol.for("@ebay/rum/logger"),s=e=>{window.dispatchEvent(new CustomEvent("@ebay/rum/ack-status",{detail:e}))};function c(e,t){!1===e&&new Error(`RUM_INLINE_ERR_CODE: ${t}`)}(t=>{const c=(()=>{let e={status:"Initialize"};const t=()=>s(e);return window.addEventListener(i,t),{updateInlinerState:t=>{e=t,s(e)},dispose:()=>window.removeEventListener(i,t)}})();try{const i=((t,i=(()=>{}))=>{if((e=>{if(!e.endpoint)throw new Error('Unable to initialize logger. "endpoint" is a required property in the input object.');if(!e.serviceName)throw new Error('Unable to initialize logger. "serviceName" is a required property in the input object.');if(e.customSchemas&&!e.namespace)throw new Error('Unable to initialize logger. "namespace" is a required property in the input object if you provide customeSchemas.')})(t),"undefined"==typeof window)return{...o((()=>{})),noop:!0};const a={...t.customSchemas,...e},s=n((e=>{return"ignoreList"in e?{...e,ignoreList:(t=e.ignoreList,new RegExp(t.map((e=>`(${e})`)).join("|"),"g"))}:e;var t})(t),a,i);return t.captureUncaught&&(e=>{window.addEventListener("error",(t=>{if(t.error instanceof Error){const n=r(t.error,"Uncaught Error Handler");e(n)}}))})(s),t.captureUnhandledRejections&&(e=>{window.addEventListener("unhandledrejection",(t=>{if(t.reason instanceof Error){const n=r(t.reason,"Unhandled Rejection Handler");e(n)}}))})(s),o(s)})(t.loggerProps,(e=>t=>{if("Error"===t.event)return((e,t)=>{e.updateInlinerState({status:"Failure",error:t.value})})(e,t);var r;e.updateInlinerState({status:(r=t.event,"Complete"===r?"Success":r),logger:o(t.value)})})(c));t.onLoggerLoad&&t.onLoggerLoad(i),window[a]=i}catch(e){c.updateInlinerState({status:"Failure",error:e})}})({onLoggerLoad:()=>{},...(()=>{c(null!==document.currentScript,1);const e=document.currentScript.dataset.inlinepayload;return c(void 0!==e,2),JSON.parse(e)})()})})();
#   </script>
#   <!--M_96613636^s0-2-1-5 s0-2-1 5-->
#   <script id="ebay-rum">
#   </script>
#   <!--M_96613636/-->
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="main" name="layout"/>
#   <link as="image" fetchpriority="high" href="https://i.ebayimg.com/images/g/Z5sAAeSw79lou1AX/s-l1600.jpg" rel="preload"/>
#   <script type="text/javascript">
#    try {
#                 window.heroImg = "https://i.ebayimg.com/images/g/Z5sAAeSw79lou1AX/s-l1600.jpg";
#             } catch (err) {
#                 console.error(err);
#             }
#   </script>
#   <!-- SEO METADATA START -->
#   <meta content="Dell Latitude 7430 14-in. FHD Touchscreen Intel i7-1265U 32GB, 512GB SSD W11 Pro | eBay" name="twitter:title">
#    <meta content="@eBay" name="twitter:site">
#     <meta content="ebay-objects:item" property="og:type">
#      <meta content="max-snippet:-1, max-image-preview:large" name="robots"/>
#      <meta content="https://i.ebayimg.com/images/g/Z5sAAeSw79lou1AX/s-l400.jpg" property="og:image"/>
#      <meta content="This is a certified refurbished product. 32GB DDR4 SDRAM. Windows 11 Professional. The HD Webcam (1280x720) paired with dual-array microphones, and high-definition audio with 2x 2W speakers enhance video conferencing, providing clear video and audio for professional communication." name="twitter:description"/>
#      <meta content="102628213125203" property="fb:app_id"/>
#      <meta content="summary" name="twitter:card"/>
#      <meta content="eBay" property="og:site_name"/>
#      <link href="https://i.ebayimg.com" rel="preconnect">
#       <meta content="unsafe-url" name="referrer"/>
#       <link href="https://ir.ebaystatic.com" rel="preconnect">
#        <meta content="Dell Latitude 7430 14-in. FHD Touchscreen Intel i7-1265U 32GB, 512GB SSD W11 Pro | eBay" property="og:title"/>
#        <link href="android-app://com.ebay.mobile/ebay/link/?nav=item.view&amp;id=375566255823&amp;referrer=http%3A%2F%2Frover.ebay.com%2Froverns%2F1%2F711-13271-9788-0%3Fmpcl%3Dhttp%253A%252F%252Fwww.ebay.com%252Fitm%252F375566255823" rel="alternate">
#         <meta content="acf32e2a69cbc2b0" name="y_key"/>
#         <meta content="en-us" http-equiv="content-language"/>
#         <title>
#          Dell Latitude 7430 14-in. FHD Touchscreen Intel i7-1265U 32GB, 512GB SSD W11 Pro | eBay
#         </title>
#         <meta content="8kHr3jd3Z43q1ovwo0KVgo_NZKIEMjthBxti8m8fYTg" name="google-site-verification"/>
#         <meta content="https://i.ebayimg.com/images/g/Z5sAAeSw79lou1AX/s-l400.jpg" name="twitter:image"/>
#         <link href="https://www.ebay.com/itm/375566255823" rel="canonical">
#          <meta content="This is a certified refurbished product. 32GB DDR4 SDRAM. Windows 11 Professional. The HD Webcam (1280x720) paired with dual-array microphones, and high-definition audio with 2x 2W speakers enhance video conferencing, providing clear video and audio for professional communication." name="description"/>
#          <meta content="https://www.ebay.com/itm/375566255823" property="og:url"/>
#          <meta content="This is a certified refurbished product. 32GB DDR4 SDRAM. Windows 11 Professional. The HD Webcam (1280x720) paired with dual-array microphones, and high-definition audio with 2x 2W speakers enhance video conferencing, providing clear video and audio for professional communication." property="og:description"/>
#          <meta content="sites-7757056108965234" name="google-adsense-account"/>
#          <meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01"/>
#          <meta content="6e11485a66d91eff" name="yandex-verification"/>
#          <!-- SEO METADATA END -->
#          <link href="https://www.ebay.com/itm/375566255823" hreflang="en-US" rel="alternate">
#           <link href="https://www.ebay.com/itm/375566255823" hreflang="x-default" rel="alternate">
#            <link href="https://ir.ebaystatic.com/rs/c/globalheaderweb/index_lcNW.3af367a8.css" rel="stylesheet" type="text/css"/>
#            <script>
#             $mbp_M_96613636="https://ir.ebaystatic.com/rs/c/r1vinode/"
#            </script>
#            <script async="" crossorigin="" src="https://ir.ebaystatic.com/rs/c/r1vinode/item_evo.marko-BII94qhq.js" type="module">
#            </script>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/attrs-CqOo7oB5.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BN5mInrO.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-D2on42zX.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/section-title-B2hpCWs0.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/sitespeed-CmaX5UfG.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/component-browser-D79P_StM.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BIpSdoaQ.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/floating-ui.dom-C456m_rE.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/style-value-KgMkCRIu.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-B-FvVsBS.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/style-bKReCrOy.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-CptkDCJ8.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/of-fallback-BruKGmXq.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BAeObIY1.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-I5e_cvjl.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/signal-DajWK6AT.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-D-n4CToV.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-yQgSMVwf.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DYSsGquq.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DXrGZtky.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BGYKV0E5.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BkwAqNjA.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-D2L38sQD.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BMIZGsDe.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DFGSBBkO.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DBqDsVRw.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/cloneDeep-D_Nuq2da.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BiA1NsJR.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-CKcGJRoO.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-CV13Mstr.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/effects-CqwFm8Ym.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DvLibwF5.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/empty-component-DW_cwbZS.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-B5dVTNrO.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/component-browser-C1jXyhHD.js" rel="modulepreload"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/attrs-Cm0mCVgl.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/section-title-CDCWeVje.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/component-browser-BgBCPprd.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/style-value-D-LVrgmZ.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/style-DYRnc_LK.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-O4TLju0v.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/signal-ChDazCEH.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-C_WOLtid.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/link-BRsiPoNA.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DrVPQZNQ.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/field-DcmYseO1.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BWv5c_TD.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-Dzs_dKUr.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DZq4-v3w.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-T5RaQPlK.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DOC1vIzZ.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-DOMuSmtG.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/cloneDeep-D6-TVvhL.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-tadR8jff.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-Dv45cvKY.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BcZ6mwM6.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/effects-CvP13oRf.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-4t_fqkMf.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/empty-component-_OuNqaPJ.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/index-BJ6TzIYr.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/item_evo-DomlNZgh.css" rel="stylesheet"/>
#            <link crossorigin="" href="https://ir.ebaystatic.com/rs/c/r1vinode/style-C3cuR-3A.css" rel="stylesheet"/>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="vi-body en-US">
#   <div class="vi-evo">
#    <div class="top-panel-container">
#     <div class="vi-global-header vi-grid" id="vi-global-header">
#      <script type="text/javascript">
#       var GHpre = {"ghxc":[],"ghxs":["gh.evo.2b"],"userAuth":false,"userId":"","fn":""}
#      </script>
#      <!--globalheaderweb#s0-1-4-->
#      <link href="https://www.ebay.com/manifest.json" rel="manifest"/>
#      <!--globalheaderweb#s0-1-4-1-0-->
#      <script>
#       (function(){const e=window.GH||{};try{var o,i;const n=e=>e==="true";const a=n("false");const d=/[\W_]/g;const s=window.location.hostname.includes("sandbox");let l="https://www.ebay.com";if(s){l=l.replace("www","sandbox")}e.__private=e.__private||{};e.C={siteId:"0",env:"production",lng:"en-US",pageId:Number("2332490"),xhrBaseUrl:l};e.__private.risk={behavior_collection_interval:JSON.parse("{\"2500857\":5000,\"2507978\":5000,\"default\":15000}"),id:(o=window.GHpre)===null||o===void 0?void 0:o.userId};e.__private.fsom={linkUrl:"https://www.m.ebay.com",linkText:"Switch to mobile site"};e.__private.ACinit={isGeo:n("false"),isQA:a,factors:JSON.parse("[\"gh.evo.2b\"]")};e.__private.isQA=a;try{var t,r;e.__private.ghx=[...(((t=window.GHpre)===null||t===void 0?void 0:t.ghxc)||[]).map((e=>e.replace(d,""))),...(((r=window.GHpre)===null||r===void 0?void 0:r.ghxs)||[]).map((e=>e.replace(d,"")))]}catch(o){e.__private.ghx=[]}e.resetCart=function(o){const i=new CustomEvent("updateCart",{detail:o});document.dispatchEvent(i);e.__private.cartCount=o};e.userAuth=((i=window.GHpre)===null||i===void 0?void 0:i.userAuth)||false;window.GH=e}catch(o){console.error(o);window.GH=e||{}}})();
#      </script>
#      <!--globalheaderweb/-->
#      <!--globalheaderweb#s0-1-4-1-2-->
#      <script>
#       window.GH.__private.scandal = {
#         isGeo: function() {return false;},
#         getPageID: function() {return 2332490;},
#         getSiteID: function() {return "0";}
#     };
#      </script>
#      <!--globalheaderweb/-->
#      <!--globalheaderweb#s0-1-4-2-0-->
#      <!--globalheaderweb/-->
#      <!--globalheaderweb^s0-1-4-3 s0-1-4 3-->
#      <!--globalheaderweb/-->
#      <!--globalheaderweb^s0-1-4-4 s0-1-4 4-->
#      <!--globalheaderweb/-->
#      <!--globalheaderweb^s0-1-4-5 s0-1-4 5-->
#      <div class="gh-sch-prom" data-marko-key="@gh-border s0-1-4-5" id="gh-gb" tabindex="-1">
#      </div>
#      <!--globalheaderweb/-->
#      <div class="ghw">
#       <header class="gh-header" data-marko-key="@gh s0-1-4" id="gh">
#        <div class="gh-a11y-skip-button">
#         <a class="gh-a11y-skip-button__link" href="#mainContent" tabindex="1">
#          Skip to main content
#         </a>
#        </div>
#        <nav class="gh-nav">
#         <div class="gh-nav__left-wrap">
#          <!--globalheaderweb#s0-1-4-8-3[0]-0-->
#          <span class="gh-identity">
#           <span class="gh-identity__srvr" data-marko-key="5 s0-1-4-8-3[0]-0" id="gh-ident-srvr-wrap">
#            <!--F#6-->
#            <span class="gh-identity__greeting">
#             Hi
#             <span>
#              <span id="gh-ident-srvr-name">
#              </span>
#              !
#             </span>
#            </span>
#            <!--F/-->
#            <!--F#7-->
#            <script>
#             (function(){
#         const pre = window.GHpre || {};
#         function hide() {
#             const wrap = document.getElementById('gh-ident-srvr-wrap');
#             if (wrap) { wrap.classList.add('gh-identity__srvr--unrec') };
#         }
#         if (pre.userAuth) {
#             const nm = document.getElementById('gh-ident-srvr-name');
#             const user = GH.C.siteId === '77' ? pre.userId || pre.fn : pre.fn || pre.userId;
#             nm && user ? nm.textContent = decodeURIComponent(user) : hide();
#         } else {
#             hide();
#         }
#     })();
#            </script>
#            <!--F/-->
#            <!--globalheaderweb^s0-1-4-8-3[0]-0-8 s0-1-4-8-3[0]-0 8-->
#            <span class="gh-identity-signed-out-unrecognized">
#             Hi!
#             <a _sp="m570.l1524" href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;sgfl=gh">
#              Sign in
#             </a>
#             <span class="hide-at-md">
#              or
#              <a _sp="m570.l2621" href="https://signup.ebay.com/pa/crte">
#               register
#              </a>
#             </span>
#            </span>
#            <!--globalheaderweb/-->
#           </span>
#          </span>
#          <!--globalheaderweb/-->
#          <span class="gh-nav-link">
#           <a _sp="m570.l3188" aria-label="Daily Deals" href="https://www.ebay.com/deals">
#            Daily Deals
#           </a>
#          </span>
#          <span class="gh-nav-link">
#           <a _sp="m570.l47233" aria-label="Brand Outlet" href="https://www.ebay.com/b/Brand-Outlet/bn_7115532402">
#            Brand Outlet
#           </a>
#          </span>
#          <span class="gh-nav-link">
#           <a _sp="m570.l174317" aria-label="Gift Cards" href="https://www.ebay.com/giftcards">
#            Gift Cards
#           </a>
#          </span>
#          <span class="gh-nav-link">
#           <a _sp="m570.l1545" aria-label="Help &amp; Contact" href="https://www.ebay.com/help/home">
#            Help &amp; Contact
#           </a>
#          </span>
#         </div>
#         <div class="gh-nav__right-wrap">
#          <!--globalheaderweb#s0-1-4-8-8-->
#          <!--globalheaderweb/-->
#          <!--globalheaderweb#s0-1-4-8-9-->
#          <!--globalheaderweb/-->
#          <span class="gh-nav-link" data-id="SELL_LINK">
#           <a _sp="m570.l1528" aria-label="Sell" href="https://www.ebay.com/sl/sell">
#            Sell
#           </a>
#          </span>
#          <!--globalheaderweb#s0-1-4-8-12-0-->
#          <div class="gh-flyout is-right-aligned gh-watchlist">
#           <!--F#1-->
#           <a _sp="m570.l47137" class="gh-flyout__target" href="https://www.ebay.com/mye/myebay/watchlist">
#            <!--F#6-->
#            <span class="gh-watchlist__target">
#             Watchlist
#            </span>
#            <!--F/-->
#            <!--F#7-->
#            <svg aria-hidden="true" class="gh-flyout__chevron icon icon--12" focusable="false" tabindex="-1">
#             <defs>
#              <symbol id="icon-chevron-down-12" viewbox="0 0 12 12">
#               <path clip-rule="evenodd" d="M1.808 4.188a.625.625 0 0 1 .884 0L6 7.495l3.308-3.307a.625.625 0 1 1 .884.885l-3.75 3.749a.625.625 0 0 1-.884 0l-3.75-3.749a.626.626 0 0 1 0-.885Z" fill-rule="evenodd">
#               </path>
#              </symbol>
#             </defs>
#             <use href="#icon-chevron-down-12">
#             </use>
#            </svg>
#            <!--F/-->
#           </a>
#           <button aria-controls="s0-1-4-8-12-0-0-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target-a11y-btn" tabindex="0">
#            Expand Watch List
#           </button>
#           <!--F/-->
#           <div class="gh-flyout__dialog" id="s0-1-4-8-12-0-0-dialog">
#            <div class="gh-flyout__box">
#             <!--F#4-->
#             <!--F/-->
#            </div>
#           </div>
#          </div>
#          <!--globalheaderweb/-->
#          <!--globalheaderweb#s0-1-4-8-13-->
#          <!--globalheaderweb^s0-1-4-8-13-0 s0-1-4-8-13 0-->
#          <div class="gh-flyout is-left-aligned gh-my-ebay">
#           <!--F#1-->
#           <a _sp="m570.l2919" class="gh-flyout__target" href="https://www.ebay.com/mys/home?source=GBH">
#            <!--F#6-->
#            <span class="gh-my-ebay__link gh-rvi-menu">
#             My eBay
#             <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron">
#             </i>
#            </span>
#            <!--F/-->
#            <!--F#7-->
#            <svg aria-hidden="true" class="gh-flyout__chevron icon icon--12" focusable="false" tabindex="-1">
#             <use href="#icon-chevron-down-12">
#             </use>
#            </svg>
#            <!--F/-->
#           </a>
#           <button aria-controls="s0-1-4-8-13-0-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target-a11y-btn" tabindex="0">
#            Expand My eBay
#           </button>
#           <!--F/-->
#           <div class="gh-flyout__dialog" id="s0-1-4-8-13-0-dialog">
#            <div class="gh-flyout__box">
#             <!--F#4-->
#             <ul class="gh-my-ebay__list">
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l1533" href="https://www.ebay.com/mye/myebay/summary" tabindex="0">
#                Summary
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l9225" href="https://www.ebay.com/mye/myebay/rvi" tabindex="0">
#                Recently Viewed
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l1535" href="https://www.ebay.com/mye/myebay/bidsoffers" tabindex="0">
#                Bids/Offers
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l1534" href="https://www.ebay.com/mye/myebay/watchlist" tabindex="0">
#                Watchlist
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l1536" href="https://www.ebay.com/mye/myebay/purchase" tabindex="0">
#                Purchase History
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l47010" href="https://www.ebay.com/mye/buyagain" tabindex="0">
#                Buy Again
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l1537" href="https://www.ebay.com/mys/home?CurrentPage=MyeBayAllSelling&amp;ssPageName=STRK:ME:LNLK:MESX&amp;source=GBH" tabindex="0">
#                Selling
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l187417" href="https://www.ebay.com/mye/myebay/saved" tabindex="0">
#                Saved Feed
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l9503" href="https://www.ebay.com/mye/myebay/savedsearches" tabindex="0">
#                Saved Searches
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l9505" href="https://www.ebay.com/mye/myebay/savedsellers" tabindex="0">
#                Saved Sellers
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l143039" href="https://www.ebay.com/g/mygarage" tabindex="0">
#                My Garage
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l177358" href="https://www.ebay.com/mysize/hub" tabindex="0">
#                Sizes
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l105163" href="https://www.ebay.com/collection/hub" tabindex="0">
#                My Collection
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l1539" href="https://mesg.ebay.com/mesgweb/ViewMessages/0" tabindex="0">
#                Messages
#               </a>
#              </li>
#              <li class="gh-my-ebay__list-item">
#               <a _sp="m570.l155388" href="https://www.ebay.com/collection/category?notionalTypeId=Vault&amp;period=1Y" tabindex="0">
#                PSA Vault
#               </a>
#              </li>
#             </ul>
#             <!--F/-->
#            </div>
#           </div>
#          </div>
#          <!--globalheaderweb/-->
#          <!--globalheaderweb/-->
#          <!--globalheaderweb#s0-1-4-8-14-0-->
#          <div class="gh-notifications">
#           <div class="gh-flyout is-right-aligned gh-flyout--icon-target">
#            <!--F#2-->
#            <button aria-controls="s0-1-4-8-14-0-1-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target">
#             <!--F#10-->
#             <span class="gh-hidden">
#              Expand Notifications
#             </span>
#             <svg aria-hidden="true" class="icon icon--20" focusable="false">
#              <defs>
#               <symbol id="icon-notification-20" viewbox="0 0 20 20">
#                <path clip-rule="evenodd" d="M6 6.982a4 4 0 0 1 8 0v2.68c0 .398.106.79.307 1.135l1.652 2.827a.25.25 0 0 1-.216.376H4.256a.25.25 0 0 1-.216-.376l1.653-2.827A2.25 2.25 0 0 0 6 9.662v-2.68ZM4 7a6 6 0 1 1 12 0v2.662a.25.25 0 0 0 .034.126l1.652 2.827c.877 1.5-.205 3.385-1.943 3.385H13a3 3 0 0 1-6 0H4.256c-1.737 0-2.819-1.885-1.942-3.385l1.652-2.827A.25.25 0 0 0 4 9.662V7Zm5 9h2a1 1 0 1 1-2 0Z" fill-rule="evenodd">
#                </path>
#               </symbol>
#              </defs>
#              <use href="#icon-notification-20">
#              </use>
#             </svg>
#             <!--F/-->
#             <!--F#11-->
#             <!--F/-->
#            </button>
#            <!--F/-->
#            <div class="gh-flyout__dialog" id="s0-1-4-8-14-0-1-dialog">
#             <div class="gh-flyout__box">
#              <!--F#4-->
#              <div class="gh-notifications__dialog">
#               <div class="gh-notifications__notloaded">
#                <span class="gh-notifications__signin">
#                 Please
#                 <a _sp="m570.l2881" href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;sgfl=nf&amp;ru=">
#                  sign-in
#                 </a>
#                 to view notifications.
#                </span>
#               </div>
#               <div class="gh-notifications__loaded" data-marko-key="@dynamic s0-1-4-8-14-0">
#               </div>
#              </div>
#              <!--F/-->
#             </div>
#            </div>
#           </div>
#          </div>
#          <!--globalheaderweb/-->
#          <div class="gh-cart">
#           <!--globalheaderweb#s0-1-4-8-15-1-->
#           <div class="gh-flyout is-right-aligned gh-flyout--icon-target">
#            <!--F#1-->
#            <a _sp="m570.l2633" class="gh-flyout__target" href="https://cart.ebay.com">
#             <!--F#6-->
#             <span aria-label="Your shopping cart contains 0 items" class="gh-cart__icon">
#              <svg aria-hidden="true" class="icon icon--20" focusable="false">
#               <defs>
#                <symbol id="icon-cart-20" viewbox="0 0 20 20">
#                 <path clip-rule="evenodd" d="M2.236 4H1a1 1 0 1 1 0-2h1.97c.458-.014.884.296 1 .755L4.855 6H17c.654 0 1.141.646.962 1.274l-1.586 5.55A3 3 0 0 1 13.491 15H7.528a3 3 0 0 1-2.895-2.21L2.236 4Zm4.327 8.263L5.4 8h10.274l-1.221 4.274a1 1 0 0 1-.962.726H7.528a1 1 0 0 1-.965-.737Z" fill-rule="evenodd">
#                 </path>
#                 <path d="M8 18.5a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0Zm6.5 1.5a1.5 1.5 0 1 0 0-3 1.5 1.5 0 0 0 0 3Z">
#                 </path>
#                </symbol>
#               </defs>
#               <use href="#icon-cart-20">
#               </use>
#              </svg>
#             </span>
#             <!--F/-->
#             <!--F#7-->
#             <!--F/-->
#            </a>
#            <button aria-controls="s0-1-4-8-15-1-0-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target-a11y-btn" tabindex="0">
#             Expand Cart
#            </button>
#            <!--F/-->
#            <div class="gh-flyout__dialog" id="s0-1-4-8-15-1-0-dialog">
#             <div class="gh-flyout__box">
#              <!--F#4-->
#              <div class="gh-cart__dialog">
#               <div class="gh-flyout-loading gh-cart__loading">
#                <span aria-label="Loading..." class="progress-spinner progress-spinner--large gh-flyout-loading__spinner" role="img">
#                 <svg aria-hidden="true" class="icon icon--30" focusable="false">
#                  <defs>
#                   <symbol fill="none" id="icon-spinner-30" viewbox="0 0 24 24">
#                    <path clip-rule="evenodd" d="M12 2C10.0222 2 8.08879 2.58649 6.4443 3.6853C4.79981 4.78412 3.51809 6.3459 2.76121 8.17317C2.00433 10.0004 1.8063 12.0111 2.19215 13.9509C2.578 15.8907 3.53041 17.6725 4.92894 19.0711C6.32746 20.4696 8.10929 21.422 10.0491 21.8079C11.9889 22.1937 13.9996 21.9957 15.8268 21.2388C17.6541 20.4819 19.2159 19.2002 20.3147 17.5557C21.4135 15.9112 22 13.9778 22 12C22 11.4477 22.4477 11 23 11C23.5523 11 24 11.4477 24 12C24 14.3734 23.2962 16.6935 21.9776 18.6668C20.6591 20.6402 18.7849 22.1783 16.5922 23.0866C14.3995 23.9948 11.9867 24.2324 9.65892 23.7694C7.33115 23.3064 5.19295 22.1635 3.51472 20.4853C1.83649 18.8071 0.693605 16.6689 0.230582 14.3411C-0.232441 12.0133 0.00519943 9.60051 0.913451 7.4078C1.8217 5.21509 3.35977 3.34094 5.33316 2.02236C7.30655 0.703788 9.62663 0 12 0C12.5523 0 13 0.447715 13 1C13 1.55228 12.5523 2 12 2Z" fill="var(--color-spinner-icon-background, #3665F3)" fill-rule="evenodd">
#                    </path>
#                    <path clip-rule="evenodd" d="M14.1805 1.17194C14.3381 0.642616 14.895 0.341274 15.4243 0.498872C17.3476 1.07149 19.0965 2.11729 20.5111 3.54055C21.9257 4.96382 22.9609 6.71912 23.5217 8.64584C23.6761 9.17611 23.3714 9.73112 22.8411 9.88549C22.3108 10.0399 21.7558 9.73512 21.6015 9.20485C21.134 7.59925 20.2715 6.13651 19.0926 4.95045C17.9138 3.76439 16.4563 2.8929 14.8536 2.41572C14.3243 2.25812 14.0229 1.70126 14.1805 1.17194Z" fill="var(--color-spinner-icon-foreground, #E5E5E5)" fill-rule="evenodd">
#                    </path>
#                   </symbol>
#                  </defs>
#                  <use href="#icon-spinner-30">
#                  </use>
#                 </svg>
#                </span>
#                <span>
#                 Loading...
#                </span>
#               </div>
#               <div data-marko-key="@dynamic s0-1-4-8-15-1" id="gh-minicart-hover-body">
#               </div>
#              </div>
#              <!--F/-->
#             </div>
#            </div>
#           </div>
#           <!--globalheaderweb/-->
#          </div>
#         </div>
#        </nav>
#        <section class="gh-header__main" data-marko-key="@gh-main s0-1-4">
#         <div class="gh-header__logo-cats-wrap">
#          <a _sp="m570.l2586" class="gh-logo" href="https://www.ebay.com" tabindex="2">
#           <svg aria-labelledby="ebayLogoTitle" height="48" id="gh-logo" viewbox="0 0 122 48.592" width="117" xmlns="http://www.w3.org/2000/svg">
#            <title id="ebayLogoTitle">
#             eBay Home
#            </title>
#            <g>
#             <path d="M24.355 22.759c-.269-5.738-4.412-7.838-8.826-7.813-4.756.026-8.544 2.459-9.183 7.915zM6.234 26.93c.364 5.553 4.208 8.814 9.476 8.785 3.648-.021 6.885-1.524 7.952-4.763l6.306-.035c-1.187 6.568-8.151 8.834-14.145 8.866C4.911 39.844.043 33.865-.002 25.759c-.05-8.927 4.917-14.822 15.765-14.884 8.628-.048 14.978 4.433 15.033 14.291l.01 1.625z" fill="#F02D2D">
#             </path>
#             <path d="M46.544 35.429c5.688-.032 9.543-4.148 9.508-10.32s-3.947-10.246-9.622-10.214-9.543 4.148-9.509 10.32 3.974 10.245 9.623 10.214zM30.652.029l6.116-.034.085 15.369c2.978-3.588 7.1-4.65 11.167-4.674 6.817-.037 14.412 4.518 14.468 14.454.045 8.29-5.941 14.407-14.422 14.454-4.463.026-8.624-1.545-11.218-4.681a33.237 33.237 0 01-.19 3.731l-5.994.034c.09-1.915.185-4.364.174-6.322z" fill="#0968F6">
#             </path>
#             <path d="M77.282 25.724c-5.548.216-8.985 1.229-8.965 4.883.013 2.365 1.94 4.919 6.7 4.891 6.415-.035 9.826-3.556 9.794-9.289v-.637c-2.252.02-5.039.054-7.529.152zm13.683 7.506c.01 1.778.071 3.538.232 5.1l-5.688.032a33.381 33.381 0 01-.225-3.825c-3.052 3.8-6.708 4.909-11.783 4.938-7.532.042-11.585-3.915-11.611-8.518-.037-6.665 5.434-9.049 14.954-9.318 2.6-.072 5.529-.1 7.945-.116v-.637c-.026-4.463-2.9-6.285-7.854-6.257-3.68.021-6.368 1.561-6.653 4.2l-6.434.035c.645-6.566 7.53-8.269 13.595-8.3 7.263-.04 13.406 2.508 13.448 10.192z" fill="#FFBD14">
#             </path>
#             <path d="M91.939 19.852l-4.5-8.362 7.154-.04 10.589 20.922 10.328-21.02 6.486-.048-18.707 37.251-6.85.039 5.382-10.348-9.887-18.393" fill="#92C821">
#             </path>
#            </g>
#           </svg>
#          </a>
#          <!--globalheaderweb#s0-1-4-11-0-->
#          <div class="gh-categories">
#           <div class="gh-flyout is-left-aligned">
#            <!--F#2-->
#            <button aria-controls="s0-1-4-11-0-1-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target" tabindex="3">
#             <!--F#10-->
#             <span class="gh-categories__title">
#              Shop by category
#             </span>
#             <!--F/-->
#             <!--F#11-->
#             <svg aria-hidden="true" class="gh-flyout__chevron icon icon--12" focusable="false" tabindex="-1">
#              <use href="#icon-chevron-down-12">
#              </use>
#             </svg>
#             <!--F/-->
#            </button>
#            <!--F/-->
#            <div class="gh-flyout__dialog" id="s0-1-4-11-0-1-dialog">
#             <div class="gh-flyout__box">
#              <!--F#4-->
#              <!--F/-->
#             </div>
#            </div>
#           </div>
#          </div>
#          <!--globalheaderweb/-->
#         </div>
#         <form action="https://www.ebay.com/sch/i.html" class="gh-search" id="gh-f" method="get" target="_top">
#          <div class="gh-search-box__wrap" id="gh-search-box">
#           <div class="gh-search__wrap">
#            <!--globalheaderweb#s0-1-4-12-4-->
#            <div class="gh-search-input__wrap" id="gh-ac-wrap">
#             <input aria-autocomplete="list" aria-expanded="false" aria-haspopup="true" aria-label="Search for anything" autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-search-input gh-tb ui-autocomplete-input" data-marko='{"oninput":"handleTextUpdate s0-1-4-12-4 false","onfocusin":"handleMarkTimer s0-1-4-12-4 false","onkeydown":"handleMarkTimer s0-1-4-12-4 false"}' data-marko-key="@input s0-1-4-12-4" id="gh-ac" maxlength="300" name="_nkw" placeholder="Search for anything" role="combobox" size="50" spellcheck="false" tabindex="4" title="Search" type="text"/>
#             <!--globalheaderweb#s0-1-4-12-4-1-0-->
#             <svg aria-hidden="true" class="gh-search-input__icon icon icon--16" data-marko-key="@svg s0-1-4-12-4-1-0" focusable="false">
#              <defs data-marko-key="@defs s0-1-4-12-4-1-0">
#               <symbol id="icon-search-16" viewbox="0 0 16 16">
#                <path d="M3 6.5a3.5 3.5 0 1 1 7 0 3.5 3.5 0 0 1-7 0Zm11.76 6.85-.021-.01-3.71-3.681-.025-.008A5.465 5.465 0 0 0 12 6.5 5.5 5.5 0 1 0 6.5 12a5.47 5.47 0 0 0 3.118-.972l3.732 3.732a1 1 0 0 0 1.41-1.41Z">
#                </path>
#               </symbol>
#              </defs>
#              <use href="#icon-search-16">
#              </use>
#             </svg>
#             <!--globalheaderweb/-->
#             <!--globalheaderweb^s0-1-4-12-4-@clear s0-1-4-12-4 @clear-->
#             <button aria-label="Clear search" class="gh-search-input__clear-btn icon-btn icon-btn--transparent icon-btn--small" data-ebayui="" data-marko='{"onclick":"handleClick s0-1-4-12-4-@clear false","onkeydown":"handleKeydown s0-1-4-12-4-@clear false","onfocus":"handleFocus s0-1-4-12-4-@clear false","onblur":"handleBlur s0-1-4-12-4-@clear false"}' type="button">
#              <!--globalheaderweb#s0-1-4-12-4-@clear-1-2-0-->
#              <svg aria-hidden="true" class="gh-search-input__clear-icon icon icon--16" data-marko-key="@svg s0-1-4-12-4-@clear-1-2-0" focusable="false">
#               <defs data-marko-key="@defs s0-1-4-12-4-@clear-1-2-0">
#                <symbol id="icon-clear-16" viewbox="0 0 16 16">
#                 <path d="M8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0Zm3.71 10.29a1 1 0 1 1-1.41 1.41L8 9.41l-2.29 2.3A1 1 0 0 1 4.3 10.3L6.59 8l-2.3-2.29a1.004 1.004 0 0 1 1.42-1.42L8 6.59l2.29-2.29a1 1 0 0 1 1.41 1.41L9.41 8l2.3 2.29Z">
#                 </path>
#                </symbol>
#               </defs>
#               <use href="#icon-clear-16">
#               </use>
#              </svg>
#              <!--globalheaderweb/-->
#             </button>
#             <!--globalheaderweb/-->
#            </div>
#            <!--globalheaderweb/-->
#            <!--globalheaderweb#s0-1-4-12-5-->
#            <select aria-label="Select a category for search" class="gh-search-categories" data-marko='{"onchange":"handleCategorySelect s0-1-4-12-5 false"}' id="gh-cat" name="_sacat" size="1" tabindex="5">
#             <option value="0">
#              All Categories
#             </option>
#            </select>
#            <!--globalheaderweb/-->
#           </div>
#          </div>
#          <input name="_from" type="hidden" value="R40"/>
#          <input name="_trksid" type="hidden" value="m570.l1313"/>
#          <!--globalheaderweb#s0-1-4-12-8-->
#          <div class="gh-search-button__wrap">
#           <!--globalheaderweb^s0-1-4-12-8-@btn s0-1-4-12-8 @btn-->
#           <button class="gh-search-button btn btn--secondary" data-ebayui="" data-marko='{"onclick":"handleClick s0-1-4-12-8-@btn false","onkeydown":"handleKeydown s0-1-4-12-8-@btn false","onfocus":"handleFocus s0-1-4-12-8-@btn false","onblur":"handleBlur s0-1-4-12-8-@btn false"}' id="gh-search-btn" role="button" tabindex="6" type="submit" value="Search">
#            <span class="gh-search-button__label">
#             Search
#            </span>
#            <!--globalheaderweb#s0-1-4-12-8-@btn-7-2-0-->
#            <svg aria-hidden="true" class="gh-search-button__icon icon icon--16" data-marko-key="@svg s0-1-4-12-8-@btn-7-2-0" focusable="false">
#             <use href="#icon-search-16">
#             </use>
#            </svg>
#            <!--globalheaderweb/-->
#           </button>
#           <!--globalheaderweb/-->
#           <a _sp="m570.l2614" class="gh-search-button__advanced-link" href="https://www.ebay.com/sch/ebayadvsearch" tabindex="7">
#            Advanced
#           </a>
#          </div>
#          <!--globalheaderweb/-->
#         </form>
#        </section>
#       </header>
#      </div>
#      <div class="widgets-placeholder" id="widgets-placeholder">
#      </div>
#      <!--globalheaderweb/-->
#      <div class="ghw" id="glbfooter" style="display:none">
#       <!--globalheaderweb#s0-1-5-1-->
#       <!--globalheaderweb/-->
#       <!--globalheaderweb#s0-1-5-2-0-->
#       <!--globalheaderweb/-->
#      </div>
#      <!-- ghw_reverted -->
#     </div>
#    </div>
#    <main role="main">
#     <div class="main-container">
#      <!--M_96613636^s0-2-1-24-4 s0-2 4-->
#      <div class="vim x-vi-evo-main-container template-evo-avip" data-testid="x-vi-evo-main-container">
#       <div data-testid="x-rx-stream">
#        <div data-src="1e732250" id="s0-2-1-24-4-3-1-0-1-0-0">
#         <!--F#@_-->
#         <noscript id="afM_96613636ph0">
#         </noscript>
#         <!--F/-->
#        </div>
#        <div data-from="asp" data-slot="TRACKING_DATA" id="s0-2-1-24-4-3-1-0-2-0">
#         <!--F#@_-->
#         <noscript id="afM_96613636ph1">
#         </noscript>
#         <!--F/-->
#        </div>
#       </div>
#       <div class="x-vi-evo-main-container__atf-breadcrumbs">
#       </div>
#       <div class="x-vi-evo-main-container__top-panel">
#        <div class="vim vi-grid x-evo-atf-top-river" data-testid="x-evo-atf-top-river">
#         <div class="vim d-vi-evo-region" data-testid="d-vi-evo-region">
#          <div class="x-ebay-live-banner x-ebay-live-banner--classic" data-testid="x-ebay-live-banner">
#           <section aria-labelledby="s0-2-1-24-4-7-1-117[1]-10-0-status" aria-roledescription="Notice" class="section-notice" role="region">
#            <span class="section-notice__main">
#             <!--F#13-->
#             <a _sp="p4429486.m174398.l149691" class="ux-action" data-click='{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"4429486","flushImmediately":false,"eventProperty":{"parentrq":"830bc3de1990a5ad242a1e7bffffff6c","pageci":"406cad0b-1487-4e42-a064-b7680f0a713b","moduledtl":"mi:174398|li:149691","sid":"p4429486.m174398.l149691"}}' data-clientpresentationmetadata='{"presentationType":"OPEN_WINDOW"}' data-testid="ux-action" data-vi-tracking='{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"4429486","flushImmediately":false,"eventProperty":{"parentrq":"830bc3de1990a5ad242a1e7bffffff6c","pageci":"406cad0b-1487-4e42-a064-b7680f0a713b","moduledtl":"mi:174398|li:149691","sid":"p4429486.m174398.l149691"}}' href="https://ebay.com/ebaylive" target="_blank">
#              <!--F#10-->
#              <span class="ux-hotness-signal-text" data-testid="ux-hotness-signal-text">
#               <span class="signal signal--recent">
#                <!--F#1-->
#                NEW
#                <!--F/-->
#               </span>
#              </span>
#              <!--F#f_1-->
#              <!--F#12[0]-->
#              <span class="ux-textspans ux-textspans--BOLD">
#               Live shopping on eBay
#              </span>
#              <!--F/-->
#              <!--F/-->
#              <div class="ux-icon" data-testid="ux-icon">
#               <svg aria-hidden="true" class="icon icon--24" focusable="false">
#                <defs>
#                 <symbol id="icon-ebay-live-24" viewbox="0 0 24 24">
#                  <path d="M6.8 3.4a1 1 0 0 1-.2 1.4A8.984 8.984 0 0 0 3 12a8.985 8.985 0 0 0 3.6 7.201 1 1 0 0 1-1.2 1.6A10.987 10.987 0 0 1 1 12c0-3.6 1.73-6.795 4.4-8.8a1 1 0 0 1 1.4.198Z">
#                  </path>
#                  <path d="M9.515 6.446a1 1 0 0 1-.28 1.387A4.994 4.994 0 0 0 7 12c0 1.738.886 3.27 2.236 4.167a1 1 0 1 1-1.107 1.666A6.994 6.994 0 0 1 5 12a6.994 6.994 0 0 1 3.129-5.833 1 1 0 0 1 1.386.28ZM14 12a2 2 0 1 1-4 0 2 2 0 0 1 4 0Zm.764-4.167a1 1 0 0 1 1.107-1.666A6.994 6.994 0 0 1 19 12a6.994 6.994 0 0 1-3.129 5.833 1 1 0 1 1-1.107-1.666A4.994 4.994 0 0 0 17 12c0-1.738-.886-3.27-2.236-4.167Z">
#                  </path>
#                  <path d="M17.4 4.8a1 1 0 0 1 1.2-1.6C21.27 5.207 23 8.4 23 12c0 3.6-1.73 6.795-4.4 8.8a1 1 0 0 1-1.2-1.599 8.985 8.985 0 0 0 3.6-7.2A8.984 8.984 0 0 0 17.4 4.8Z">
#                  </path>
#                 </symbol>
#                </defs>
#                <use href="#icon-ebay-live-24">
#                </use>
#               </svg>
#              </div>
#              <!--F#f_1-->
#              <!--F#12[0]-->
#              <span class="ux-textspans">
#               Tune in to card breaks, style inspo, and more from top sellers.
#              </span>
#              <!--F/-->
#              <!--F/-->
#              <span class="x-ebay-live-banner__live-link" data-testid="ux-textual-display">
#               <!--F#12[0]-->
#               <span class="ux-textspans ux-textspans--PSEUDOLINK">
#                Join a livestream
#               </span>
#               <!--F/-->
#              </span>
#              <!--F/-->
#             </a>
#             <!--F/-->
#            </span>
#           </section>
#          </div>
#          <div class="vim x-alert-module" data-testid="x-alert-module" data-viewport='{"trackableId":"01K61GQH88JXQQTSFVDPPFBGPR"}'>
#          </div>
#          <div class="vim vim-ds6 x-rx-slot x-rx-slot--101224" data-testid="x-rx-slot-101224">
#           <div data-from="asp" data-slot="PLACEMENT_101224" id="s0-2-1-24-4-7-1-114[3]-1-0-@PLACEMENT_101224-0">
#            <!--F#@_-->
#            <noscript id="afM_96613636ph2">
#            </noscript>
#            <!--F/-->
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="center-panel-container vi-mast" id="CenterPanel">
#        <div class="vi-grid">
#         <div class="vi-mast__grid vi-mast__grid--DEFAULT">
#          <div class="picture-panel-container vi-mast__col-left" id="PicturePanel">
#           <div class="vim x-evo-atf-left-river x-evo-atf-left-river--share" data-testid="x-evo-atf-left-river">
# ...
#   </script>
#   <div id="afM_966136368" style="display:none">
#    <div id="placement101224">
#    </div>
#    <script>
#    </script>
#    <script async="" type="module">
#     import { render } from "https://ir.ebaystatic.com/cr/ads/merch/merch-ui-component-with-css-5-39-21.js";(function(i18n) { if (!i18n.hasOwnProperty('common')) { i18n.common = { newWindow: 'opens in a new window or tab' };}}(window.$i18n || (window.$i18n = {})));render({"model":{"modules":{"MERCH_PLACEMENT_101224":{"_type":"ADS_AND_MERCH_LIST_V2","meta":{"name":"lex6aspects-mot","trackingList":[{"eventFamily":"ADV","eventAction":"VIEW","operationId":"4429486","flushImmediately":false,"eventProperty":{"meid":"28202cc1db084ecfaf985538c55d8063","numericId":"20200818143230","parentrq":"830bc3de1990a5ad242a1e7bffffff6c","adctrldata":"ao%253D1%2526asc%253D292798%252C292122%2526meid%253D28202cc1db084ecfaf985538c55d8063%2526pid%253D101224%2526pg%253D2332490%2526algv%253DDefaultOrganicWebV9BertRefreshRankerWithCassiniEmbRecall%2526cs%253D%2526va%253D","adctrl":"AD_MDL_VIEW","moduledtl":"mi:-1|c:20200818143230","pltid":"101224","algo":"HOMESPLICE.SIM.DefaultOrganicWebV9BertRefreshRankerWithCassiniEmbRecall","trackableId":"01K61GQHJR4QBGEJDQS8ZM0T9H","interaction":"wwFVrK2vRE0lhQI0MDFLNjFHUUhKUjRRQkdFSkRRUzhaTTBUOUgAAAAAAA=="}}],"moduleIdentification":{"instanceId":"101224","sojournerModuleId":"-1","uxComponentGroup":"lex6aspects-mot"},"viewportTracking":{"trackableId":"01K61GQHJR4QBGEJDQS8ZM0T9H"},"domain":"https://www.ebay.com","latency":583},"containers":[{"_type":"CardListContainer","cardContainers":[{"_type":"CardContainer","controls":{"slider":{"_type":"SliderControls","action":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[]}},"carousel":{"_type":"CarouselControls","previous":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[],"accessibilityText":"Go to the previous slide, People who viewed this item also viewed - Carousel"},"next":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[],"accessibilityText":"Go to the next slide, People who viewed this item also viewed - Carousel"}}},"title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"People who viewed this item also viewed"}]},"cards":[{"_type":"ItemCard","action":{"_type":"Action","type":"NAV","name":"VIEW_ITEM","params":{"listingId":"226890126930"},"trackingList":[{"actionKind":"NAV","operationId":"4429486","flushImmediately":false,"eventProperty":{"parentrq":"830bc3de1990a5ad242a1e7bffffff6c","amdata":"amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D292798%2C292122%26meid%3D28202cc1db084ecfaf985538c55d8063%26pid%3D101224%26rk%3D1%26rkt%3D5%26sd%3D375566255823%26itm%3D226890126930%26pmt%3D1%26noa%3D0%26pg%3D2332490%26algv%3DDefaultOrganicWebV9BertRefreshRankerWithCassiniEmbRecall%26brand%3DDell%26tu%3D01K61GQHJMZAEAPZJ4DTXEBXDG","ampid":"PL_CLK","checksum":"22689012693028202cc1db084ecfaf985538c55d8063","ammiid":"28202cc1db084ecfaf985538c55d8063","enc":"","sid":"p4429486.m-1.c20200818143230"}}],"URL":"https://www.ebay.com/itm/226890126930?_trkparms=amclksrc%3DITM%26aid%3D1110006%26algo%3DHOMESPLICE.SIM%26ao%3D1%26asc%3D292798%2C292122%26meid%3D28202cc1db084ecfaf985538c55d8063%26pid%3D101224%26rk%3D1%26rkt%3D5%26sd%3D375566255823%26itm%3D226890126930%26pmt%3D1%26noa%3D0%26pg%3D2332490%26algv%3DDefaultOrganicWebV9BertRefreshRankerWithCassiniEmbRecall%26brand%3DDell&_trksid=p2332490.c101224.m-1&itmprp=cksum%3A22689012693028202cc1db084ecfaf985538c55d8063%7Cenc%3AAQAKAAABIFpV4T02GSLWmLmcYHS%252Bawhg9HB3NVAH8KQdy74hckvfm%252BTv7AoY9bWSvyrWMwnykYfzYbkMtous8borg3MTxgfjmI2SPrmpGHPKr1elPCPdEobdjYoGwcuL5GkC%252FlsgYI6rFXOZRm91dlUd72Ai41RRK4D3rqejm033fwBNY22W4KBcwusEvdag2RCSnh547SEaoUYB%25 ...
#    </script>
#    <noscript id="afM_96613636ph11">
#    </noscript>
#   </div>
#   <div id="afM_9661363611" style="display:none">
#   </div>
#   <script>
#    $afM_96613636(8);$afM_96613636(11)
#   </script>
#   <div id="afM_966136369" style="display:none">
#    <div id="placement101875">
#    </div>
#    <script>
#    </script>
#    <script async="" type="module">
#     import { render } from "https://ir.ebaystatic.com/cr/ads/merch/merch-ui-component-with-css-5-39-21.js";(function(i18n) { if (!i18n.hasOwnProperty('common')) { i18n.common = { newWindow: 'opens in a new window or tab' };}}(window.$i18n || (window.$i18n = {})));render({"model":{"modules":{"MERCH_PLACEMENT_101875":{"_type":"ADS_AND_MERCH_LIST_V2","meta":{"name":"recs-below-hero","trackingList":[{"eventFamily":"ADV","eventAction":"VIEW","operationId":"4429486","flushImmediately":false,"eventProperty":{"meid":"b71575ebc2074bd3a139fd8bbe263a0a","numericId":"20231107084023","parentrq":"830bc3de1990a5ad242a1e7bffffff6c","adctrldata":"ao%253D1%2526asc%253D292798%252C292122%2526meid%253Db71575ebc2074bd3a139fd8bbe263a0a%2526pid%253D101875%2526pg%253D2332490%2526algv%253DSimVIDwebV3WithCPCExpansionEmbeddingSearchQuerySemanticBroadMatchSingularityRecallReplaceKnnV4WithVectorDbNsOptHotPlRecallCIICentroidCoviewCPCAuto%2526cs%253D%2526va%253D","adctrl":"AD_MDL_VIEW","moduledtl":"mi:1851|c:20231107084023","pltid":"101875","algo":"HOMESPLICE.SIM.SimVIDwebV3WithCPCExpansionEmbeddingSearchQuerySemanticBroadMatchSingularityRecallReplaceKnnV4WithVectorDbNsOptHotPlRecallCIICentroidCoviewCPCAuto","trackableId":"01K61GQHKGYE8PWVHPXF3YV946","interaction":"wwFVrK2vRE0lhQI0MDFLNjFHUUhLR1lFOFBXVkhQWEYzWVY5NDYAAAAAAA=="}}],"moduleIdentification":{"instanceId":"101875","sojournerModuleId":"1851","uxComponentGroup":"recs-below-hero"},"viewportTracking":{"trackableId":"01K61GQHKGYE8PWVHPXF3YV946"},"domain":"https://www.ebay.com","latency":583},"containers":[{"_type":"CardListContainer","cardContainers":[{"_type":"CardContainer","controls":{"slider":{"_type":"SliderControls","action":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[]}},"carousel":{"_type":"CarouselControls","previous":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[],"accessibilityText":"Go to the previous slide, Similar Items - Carousel"},"next":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[],"accessibilityText":"Go to the next slide, Similar Items - Carousel"}}},"title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Similar Items"}]},"subTitle":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Sponsored"}]},"seeAll":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"See all"}],"accessibilityText":"See all","action":{"_type":"Action","type":"NAV","name":"MERCH","params":{"placement_title":"i18n.Tag_SIs","sourceModuleId":"101875","item_id":"375566255823","algos":"HOMESPLICE.SIM.SimVIDwebV3WithCPCExpansionEmbeddingSearchQuerySemanticBroadMatchSingularityRecallReplaceKnnV4WithVectorDbNsOptHotPlRecallCIICentroidCoviewCPCAuto","placement_subTitle":"i18n.ModuleSubTitle_Sponsored","homespliceOverrideConfig":"{splice.cpc-config-dweb.smart-price-parmas.enable-cvr-calibration-by-l2=false,splice.cpc-config-dweb.smart-price-parmas.enable-roas-calibration-by-l2=true,splice.cpc-config-dweb.smart-price-parmas.target-roas=7.2}"},"trackingList":[{"eventFamily":"ADV","eventAction":"ACTN","actionKind":"NAVSRC","operationId":"4429486","flushImmediately":false,"eventProperty":{"meid":"b71575ebc2074bd3a139fd8bbe263a0a","numericId":"20231107084023","parentrq":"830bc3de1990a5ad242a1e7bffffff6c","adctrl":"AD_CONTROL_NAV","moduledtl":"mi:1851|c:20231107084023","pltid":"101875"}}],"accessibilityText":"See all","URL":"https://www.ebay.com/recs?component=recs-below-hero&item_id=375566255823&algos=HOMESPLICE.SIM.SimVIDwebV3WithCPCExpansionEmbeddingSearchQuerySemanticBroadMatchSingularityRecallReplaceKnnV4WithVectorDbNsOptHotPlRecallCIICentroidCoviewCPCAuto&placement_title=i18n.Tag_SIs&sourceModuleId=101875&homespliceOverrideConfig=%7Bsplice.cpc-config-dweb.smart-price-parmas.enable-cvr-calibration-by-l2%3Dfalse%2Csplice.cpc-config-dweb.smart-price-parmas.enable-roas-calibration-by-l2%3Dtrue%2Csplice.cpc-config-dweb.smart-price-parmas.target-roas%3D7.2%7D&placement_subTitle=i18n.ModuleSubTitl ...
#    </script>
#    <noscript id="afM_96613636ph12">
#    </noscript>
#   </div>
#   <div id="afM_9661363612" style="display:none">
#   </div>
#   <div id="afM_9661363610" style="display:none">
#    <div id="placement101196">
#    </div>
#    <script>
#    </script>
#    <script async="" type="module">
#     import { render } from "https://ir.ebaystatic.com/cr/ads/merch/merch-ui-component-with-css-5-39-21.js";(function(i18n) { if (!i18n.hasOwnProperty('common')) { i18n.common = { newWindow: 'opens in a new window or tab' };}}(window.$i18n || (window.$i18n = {})));render({"model":{"modules":{"MERCH_PLACEMENT_101196":{"_type":"ADS_AND_MERCH_LIST_V2","meta":{"name":"lex6aspects-5-items","trackingList":[{"eventFamily":"ADV","eventAction":"VIEW","operationId":"4429486","flushImmediately":false,"eventProperty":{"meid":"ccecb377487245378f7c517fcb91ccca","numericId":"20201210111451","parentrq":"830bc3de1990a5ad242a1e7bffffff6c","adctrldata":"ao%253D1%2526asc%253D292798%252C292122%2526meid%253Dccecb377487245378f7c517fcb91ccca%2526pid%253D101196%2526pg%253D2332490%2526algv%253DSimplAMLv5PairwiseWebWithBBEV2bAndUBSourceDemotionWithUltimatelyBoughtOfCoviewV1%2526cs%253D%2526va%253D","adctrl":"AD_MDL_VIEW","moduledtl":"mi:2219|c:20201210111451","pltid":"101196","algo":"HOMESPLICE.SIM.SimplAMLv5PairwiseWebWithBBEV2bAndUBSourceDemotionWithUltimatelyBoughtOfCoviewV1","trackableId":"01K61GQHMCHF2J6P9N1AZSXWQE","interaction":"wwFVrK2vRE0lhQI0MDFLNjFHUUhNQ0hGMko2UDlOMUFaU1hXUUUAAAAAAA=="}}],"moduleIdentification":{"instanceId":"101196","sojournerModuleId":"2219","uxComponentGroup":"lex6aspects-5-items"},"viewportTracking":{"trackableId":"01K61GQHMCHF2J6P9N1AZSXWQE"},"domain":"https://www.ebay.com","latency":583},"containers":[{"_type":"CardListContainer","cardContainers":[{"_type":"CardContainer","controls":{"slider":{"_type":"SliderControls","action":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[]}},"carousel":{"_type":"CarouselControls","previous":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[],"accessibilityText":"Go to the previous slide, Customers ultimately bought - Carousel"},"next":{"_type":"Action","type":"OPERATION","name":"VIEW_MERCH","trackingList":[],"accessibilityText":"Go to the next slide, Customers ultimately bought - Carousel"}}},"title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Customers ultimately bought"}]},"subTitle":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Sponsored"}]},"seeAll":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"See all"}],"accessibilityText":"See all","action":{"_type":"Action","type":"NAV","name":"MERCH","params":{"placement_title":"i18n.Customers_Ultimately_Bought","sourceModuleId":"101196","item_id":"375566255823","algos":"HOMESPLICE.SIM.SimplAMLv5PairwiseWebWithBBEV2bAndUBSourceDemotionWithUltimatelyBoughtOfCoviewV1","placement_subTitle":"i18n.ModuleSubTitle_Sponsored","homespliceOverrideConfig":"{splice.cpc-config-dweb.smart-price-parmas.enable-cvr-calibration-by-l2=false,splice.cpc-config-dweb.smart-price-parmas.enable-roas-calibration-by-l2=true,splice.cpc-config-dweb.smart-price-parmas.target-roas=7.2}"},"trackingList":[{"eventFamily":"ADV","eventAction":"ACTN","actionKind":"NAVSRC","operationId":"4429486","flushImmediately":false,"eventProperty":{"meid":"ccecb377487245378f7c517fcb91ccca","numericId":"20201210111451","parentrq":"830bc3de1990a5ad242a1e7bffffff6c","adctrl":"AD_CONTROL_NAV","moduledtl":"mi:2219|c:20201210111451","pltid":"101196"}}],"accessibilityText":"See all","URL":"https://www.ebay.com/recs?component=lex6aspects-5-items&item_id=375566255823&algos=HOMESPLICE.SIM.SimplAMLv5PairwiseWebWithBBEV2bAndUBSourceDemotionWithUltimatelyBoughtOfCoviewV1&placement_title=i18n.Customers_Ultimately_Bought&sourceModuleId=101196&homespliceOverrideConfig=%7Bsplice.cpc-config-dweb.smart-price-parmas.enable-cvr-calibration-by-l2%3Dfalse%2Csplice.cpc-config-dweb.smart-price-parmas.enable-roas-calibration-by-l2%3Dtrue%2Csplice.cpc-config-dweb.smart-price-parmas.target-roas%3D7.2%7D&placement_subTitle=i18n.ModuleSubTitle_Sponsored"}},"cards":[{"_type":"ItemCard","action":{"_type":"Action","type":"NAV","name":"VIEW_ITEM","params":{"listingId":"286304896630"},"trackingList":[{"actionKind" ...
#    </script>
#    <noscript id="afM_96613636ph13">
#    </noscript>
#   </div>
#   <div id="afM_9661363613" style="display:none">
#   </div>
#   <script>
#    $afM_96613636(9);$afM_96613636(12);$afM_96613636(10);$afM_96613636(13)
#   </script>
#   <div id="afM_966136366" style="display:none">
#   </div>
#   <div id="afM_966136367" style="display:none">
#    <script>
#     const _PLACEMENT_101886_div = document.querySelector('[data-slot="PLACEMENT_101886"]'); if (_PLACEMENT_101886_div) _PLACEMENT_101886_div.textContent="";
#    </script>
#    <noscript id="afM_96613636ph14">
#    </noscript>
#   </div>
#   <div id="afM_9661363614" style="display:none">
#   </div>
#   <div id="afM_966136361" style="display:none">
#   </div>
#   <script>
#    $afM_96613636(6);$afM_96613636(7);$afM_96613636(14);$afM_96613636(1);$M_96613636_C=(window.$M_96613636_C||[]).concat({"l":1})
#   </script>
#  </body>
# </html>
# <!--M_96613636/-->
# <!--M_96613636/-->
# <!-- RcmdId vinode,RlogId t6q4pnmjbb70ehmq%3C%3Dq4pnmjbb70ehmq%2B%3F6a%600%3Bg01a(rbpv747(n2%7Bh0-199830bc3dd-0x1304 -->
# <!-- SiteId: 0, Environment: production, AppName: r1vinode, PageId: 2332490 -->
# <script type="text/javascript">
#  (function(scope){var CosHeaders={"X_EBAY_C_TRACKING":"guid=830bc3f11990a5ad2426005bfffffce3,pageid=2332490,cobrandId=0"};scope.cosHeadersInfo={getCosHeaders:function(){return CosHeaders;},getTrackingHeaders:function(){return CosHeaders.X_EBAY_C_TRACKING;}};})(window)
# </script>

# %%
listingSoup.find_all('title')
# Out:
# [<title>Dell Latitude 7430 14-in. FHD Touchscreen Intel i7-1265U 32GB, 512GB SSD W11 Pro | eBay</title>,
#  <title id="ebayLogoTitle">eBay Home</title>,
#  <title id="s0-2-1-24-4-17-1-32[3]-3-3-6-0-8-4-0-text">More information - About this item condition</title>,
#  <title id="s0-2-1-24-4-17-1-29[11]-1-8[0[LIST_1_COLUMN]]-8[0[@payments-0]]-9[0]-2-12[14]-3-62-0-0-text">Diners Club</title>]

# %%
listingSoup.find_all('div', {'x-item-description-child'})
# Out:
# []
